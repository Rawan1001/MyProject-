# %%
#MTA project 1 EDA
#SDAIA Academy
#Rawan Al-Ahmadi

# %%
import os 
import pandas as pd
import numpy as np
import glob as gg
import seaborn as sns
import matplotlib.pyplot as plt
import sqlalchemy
from sqlalchemy import create_engine
import sqlite3
from difflib import SequenceMatcher
import re
import datetime as dt
# %matplotlib inline

# %% [markdown]
# # Loading data:

# %%
#path to my files for the monthes of 6,7,8,9 of 2019 
Path_csv = "/Users/rawan/Desktop/MyProject1/data"

Csv_all =gg.glob(Path_csv + "/*.txt")
list_of_allcsv= []# all data in will be added to the list

for i in Csv_all:
    df = pd.read_csv(i)
    list_of_allcsv.append(df)

# %%
mta_all_files= pd.concat(list_of_allcsv)#all files togther

# %%
mta_all_files.head()
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/25/2019  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/25/2019  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/25/2019  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/25/2019  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/25/2019  16:00:00
#
#       DESC  ENTRIES  \
# 0  REGULAR  7071830
# 1  REGULAR  7071844
# 2  REGULAR  7071864
# 3  REGULAR  7071943
# 4  REGULAR  7072182
#
#    EXITS
# 0                                            2396411
# 1                                            2396415
# 2                                            2396443
# 3                                            2396500
# 4                                            2396555

# %% [markdown]
# # connecting to the data base:

# %%
engine = create_engine("sqlite:///C:/Users/rawan/Desktop/MyProject1/MyData1.db", echo= False)
conn = sqlite3.connect("C:///Users//rawan//Desktop//MyProject1//MyData1.db")

# %%
x = pd.read_sql("SELECT * FROM allfiles limit 30;", conn)
x
# Out:
#      C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0   A002  R051  02-00-00   59 ST  NQR456W      BMT  05/25/2019  00:00:00
# 1   A002  R051  02-00-00   59 ST  NQR456W      BMT  05/25/2019  04:00:00
# 2   A002  R051  02-00-00   59 ST  NQR456W      BMT  05/25/2019  08:00:00
# 3   A002  R051  02-00-00   59 ST  NQR456W      BMT  05/25/2019  12:00:00
# 4   A002  R051  02-00-00   59 ST  NQR456W      BMT  05/25/2019  16:00:00
# 5   A002  R051  02-00-00   59 ST  NQR456W      BMT  05/25/2019  20:00:00
# 6   A002  R051  02-00-00   59 ST  NQR456W      BMT  05/26/2019  00:00:00
# 7   A002  R051  02-00-00   59 ST  NQR456W      BMT  05/26/2019  04:00:00
# 8   A002  R051  02-00-00   59 ST  NQR456W      BMT  05/26/2019  08:00:00
# 9   A002  R051  02-00-00   59 ST  NQR456W      BMT  05/26/2019  12:00:00
# 10  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/26/2019  16:00:00
# 11  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/26/2019  20:00:00
# 12  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/27/2019  00:00:00
# 13  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/27/2019  04:00:00
# 14  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/27/2019  08:00:00
# 15  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/27/2019  12:00:00
# 16  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/27/2019  16:00:00
# 17  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/27/2019  20:00:00
# 18  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/28/2019  00:00:00
# 19  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/28/2019  04:00:00
# 20  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/28/2019  08:00:00
# 21  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/28/2019  12:00:00
# 22  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/28/2019  16:00:00
# 23  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/28/2019  20:00:00
# 24  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/29/2019  00:00:00
# 25  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/29/2019  04:00:00
# 26  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/29/2019  08:00:00
# 27  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/29/2019  12:00:00
# 28  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/29/2019  16:00:00
# 29  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/29/2019  20:00:00
#
#        DESC  ENTRIES    EXITS
# 0   REGULAR  7071830  2396411
# 1   REGULAR  7071844  2396415
# 2   REGULAR  7071864  2396443
# 3   REGULAR  7071943  2396500
# 4   REGULAR  7072182  2396555
# 5   REGULAR  7072456  2396593
# 6   REGULAR  7072639  2396608
# 7   REGULAR  7072662  2396613
# 8   REGULAR  7072673  2396619
# 9   REGULAR  7072746  2396665
# 10  REGULAR  7072929  2396705
# 11  REGULAR  7073114  2396741
# 12  REGULAR  7073233  2396759
# 13  REGULAR  7073244  2396762
# 14  REGULAR  7073259  2396793
# 15  REGULAR  7073338  2396844
# 16  REGULAR  7073567  2396884
# 17  REGULAR  7073837  2396919
# 18  REGULAR  7073967  2396939
# 19  REGULAR  7073976  2396943
# 20  REGULAR  7074031  2397056
# 21  REGULAR  7074206  2397270
# 22  REGULAR  7074530  2397330
# 23  REGULAR  7075260  2397410
# 24  REGULAR  7075460  2397436
# 25  REGULAR  7075475  2397439
# 26  REGULAR  7075526  2397541
# 27  REGULAR  7075714  2397795
# 28  REGULAR  7076049  2397864
# 29  REGULAR  7076789  2397944

# %% [markdown]
# Checking the Data:

# %%
mta_all_files.columns
# Out:
# Index(['C/A', 'UNIT', 'SCP', 'STATION', 'LINENAME', 'DIVISION', 'DATE', 'TIME',
#        'DESC', 'ENTRIES',
#        'EXITS                                                               '],
#       dtype='object')

# %% [markdown]
# "Each compination of C/A, UNIT, SCP, and STATION represents a unique turnstile.
# Where:
# - C/A: Control Area.
# - UNIT: Remote Unit for a station.
# - SCP: Subunit Channel Position represents an specific address for a device.
# - STATION: Represents the station name the device is located at.
#
# - Date is recorded every 4 hours, and the ENTRIES and EXITS columns are cumulative."

# %%
mta_all_files.tail()
# Out:
#           C/A  UNIT       SCP        STATION LINENAME DIVISION        DATE  \
# 205331  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  09/27/2019
# 205332  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  09/27/2019
# 205333  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  09/27/2019
# 205334  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  09/27/2019
# 205335  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  09/27/2019
#
#             TIME     DESC  ENTRIES  \
# 205331  05:00:00  REGULAR     5554
# 205332  09:00:00  REGULAR     5554
# 205333  13:00:00  REGULAR     5554
# 205334  17:00:00  REGULAR     5554
# 205335  21:00:00  REGULAR     5554
#
#         EXITS
# 205331                                                420
# 205332                                                420
# 205333                                                420
# 205334                                                420
# 205335                                                420

# %%
mta_all_files.shape
# Out:
# (3714064, 11)

# %%
mta_all_files.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3714064 entries, 0 to 205335
# Data columns (total 11 columns):
#  #   Column                                                                Dtype
# ---  ------                                                                -----
#  0   C/A                                                                   object
#  1   UNIT                                                                  object
#  2   SCP                                                                   object
#  3   STATION                                                               object
#  4   LINENAME                                                              object
#  5   DIVISION                                                              object
#  6   DATE                                                                  object
#  7   TIME                                                                  object
#  8   DESC                                                                  object
#  9   ENTRIES                                                               int64
#  10  EXITS                                                                 int64
# dtypes: int64(2), object(9)
# memory usage: 340.0+ MB

# %%
mta_all_files.describe()
# Out:
#             ENTRIES  \
# count  3.714064e+06
# mean   4.219184e+07
# std    2.151177e+08
# min    0.000000e+00
# 25%    2.893640e+05
# 50%    2.087000e+06
# 75%    6.677386e+06
# max    2.129289e+09
#
#        EXITS
# count                                       3.714064e+06
# mean                                        3.466461e+07
# std                                         1.982552e+08
# min                                         0.000000e+00
# 25%                                         1.197578e+05
# 50%                                         1.194266e+06
# 75%                                         4.581015e+06
# max                                         2.124055e+09

# %% [markdown]
# # Cleaning the data:

# %%
#checking the number of duplicates in the MTA data

mta_all_files.shape
duplicate_number= mta_all_files[mta_all_files.duplicated()]
print("The number of duplicated rows are:", duplicate_number.shape)
# Out:
# The number of duplicated rows are: (0, 11)

# %%
#cleaning the white space from columns names

mta_all_files.columns = mta_all_files.columns.str.strip()

# %%
#Making a Date_Time column

mta_all_files['Date_Time'] = pd.to_datetime((mta_all_files.DATE + ' ' + mta_all_files.TIME), format='%m/%d/%Y %H:%M:%S')

# %%
mta_all_files.head()
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/25/2019  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/25/2019  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/25/2019  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/25/2019  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/25/2019  16:00:00
#
#       DESC  ENTRIES    EXITS           Date_Time
# 0  REGULAR  7071830  2396411 2019-05-25 00:00:00
# 1  REGULAR  7071844  2396415 2019-05-25 04:00:00
# 2  REGULAR  7071864  2396443 2019-05-25 08:00:00
# 3  REGULAR  7071943  2396500 2019-05-25 12:00:00
# 4  REGULAR  7072182  2396555 2019-05-25 16:00:00

# %%
#creating a column with the day names 

weekdays_names = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday','Saturday','Sunday']
mta_all_files['DATE'][1]
mta_all_files['Dayofweek'] = [weekdays_names[dt.datetime.strptime(dstring,'%m/%d/%Y')
                                             .weekday()] for dstring in mta_all_files.DATE.tolist()]

# %%
mta_all_files.head()
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/25/2019  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/25/2019  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/25/2019  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/25/2019  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/25/2019  16:00:00
#
#       DESC  ENTRIES    EXITS           Date_Time Dayofweek
# 0  REGULAR  7071830  2396411 2019-05-25 00:00:00  Saturday
# 1  REGULAR  7071844  2396415 2019-05-25 04:00:00  Saturday
# 2  REGULAR  7071864  2396443 2019-05-25 08:00:00  Saturday
# 3  REGULAR  7071943  2396500 2019-05-25 12:00:00  Saturday
# 4  REGULAR  7072182  2396555 2019-05-25 16:00:00  Saturday

# %%
#mask to see if there is any duplicated rows

mask = ((mta_all_files["C/A"] == "A002") &
        (mta_all_files["UNIT"] == "R051") & 
        (mta_all_files["SCP"] == "02-00-00") & 
        (mta_all_files["STATION"] == "59 ST"))

mta_all_files[mask].head()
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/25/2019  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/25/2019  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/25/2019  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/25/2019  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/25/2019  16:00:00
#
#       DESC  ENTRIES    EXITS           Date_Time Dayofweek
# 0  REGULAR  7071830  2396411 2019-05-25 00:00:00  Saturday
# 1  REGULAR  7071844  2396415 2019-05-25 04:00:00  Saturday
# 2  REGULAR  7071864  2396443 2019-05-25 08:00:00  Saturday
# 3  REGULAR  7071943  2396500 2019-05-25 12:00:00  Saturday
# 4  REGULAR  7072182  2396555 2019-05-25 16:00:00  Saturday

# %%
# Check to verify that "C/A", "UNIT", "SCP", "STATION", "DATE_TIME" is unique 

(mta_all_files
 .groupby(["C/A", "UNIT", "SCP", "STATION", "Date_Time"])
 .ENTRIES.count()
 .reset_index()
 .sort_values("ENTRIES", ascending=False)).head(5)
# Out:
#           C/A  UNIT       SCP         STATION           Date_Time  ENTRIES
# 2977859  R249  R179  01-05-00           86 ST 2019-06-27 00:00:00        2
# 2632964  R174  R034  00-00-02          125 ST 2019-06-08 00:00:00        2
# 93757    A034  R170  03-05-03  14 ST-UNION SQ 2019-08-12 01:00:00        2
# 93758    A034  R170  03-05-03  14 ST-UNION SQ 2019-08-12 05:00:00        2
# 93759    A034  R170  03-05-03  14 ST-UNION SQ 2019-08-12 09:00:00        2

# %%
# Get rid of the duplicate entry

mta_all_files.sort_values(["C/A", "UNIT", "SCP", "STATION", "Date_Time"], 
                          inplace=True, ascending=False)
mta_all_files.drop_duplicates(subset=["C/A", "UNIT", "SCP", "STATION", "Date_Time"], inplace=True)

# %%
# sanity Check to verify that "C/A", "UNIT", "SCP", "STATION", "DATE_TIME" is unique

(mta_all_files
 .groupby(["C/A", "UNIT", "SCP", "STATION", "Date_Time"])
 .ENTRIES.count()
 .reset_index()
 .sort_values("ENTRIES", ascending=False)).head(5)
# Out:
#           C/A  UNIT       SCP         STATION           Date_Time  ENTRIES
# 0        A002  R051  02-00-00           59 ST 2019-05-25 00:00:00        1
# 2476023  R138  R293  00-03-04  34 ST-PENN STA 2019-07-25 22:00:00        1
# 2475997  R138  R293  00-03-04  34 ST-PENN STA 2019-07-21 14:00:00        1
# 2475998  R138  R293  00-03-04  34 ST-PENN STA 2019-07-21 18:00:00        1
# 2475999  R138  R293  00-03-04  34 ST-PENN STA 2019-07-21 22:00:00        1

# %% [markdown]
# # Dealing with DESC column:

# %%
mta_all_files.DESC.value_counts()
# Out:
# REGULAR       3698611
# RECOVR AUD      15397
# Name: DESC, dtype: int64

# %%
def remove_RECOVR(mta_all_files):
    mta_all_files = mta_all_files[mta_all_files.DESC == 'REGULAR']
    #Dropping all the rows that are not REGULAR
    return mta_all_files
mta_all_files = remove_RECOVR(mta_all_files)

# %%
mta_all_files.DESC.value_counts()
# Out:
# REGULAR    3698611
# Name: DESC, dtype: int64

# %%
mta_all_files.head()
# Out:
#           C/A  UNIT       SCP        STATION LINENAME DIVISION        DATE  \
# 205335  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  09/27/2019
# 205334  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  09/27/2019
# 205333  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  09/27/2019
# 205332  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  09/27/2019
# 205331  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  09/27/2019
#
#             TIME     DESC  ENTRIES  EXITS           Date_Time Dayofweek
# 205335  21:00:00  REGULAR     5554    420 2019-09-27 21:00:00    Friday
# 205334  17:00:00  REGULAR     5554    420 2019-09-27 17:00:00    Friday
# 205333  13:00:00  REGULAR     5554    420 2019-09-27 13:00:00    Friday
# 205332  09:00:00  REGULAR     5554    420 2019-09-27 09:00:00    Friday
# 205331  05:00:00  REGULAR     5554    420 2019-09-27 05:00:00    Friday

# %%
# Dropping the Desc Column. To prevent errors in multiple run of cell, errors on drop is ignored

mta_all_files = mta_all_files.drop(["DESC"], axis=1, errors="ignore")
mta_all_files.head()
# Out:
#           C/A  UNIT       SCP        STATION LINENAME DIVISION        DATE  \
# 205335  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  09/27/2019
# 205334  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  09/27/2019
# 205333  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  09/27/2019
# 205332  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  09/27/2019
# 205331  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  09/27/2019
#
#             TIME  ENTRIES  EXITS           Date_Time Dayofweek
# 205335  21:00:00     5554    420 2019-09-27 21:00:00    Friday
# 205334  17:00:00     5554    420 2019-09-27 17:00:00    Friday
# 205333  13:00:00     5554    420 2019-09-27 13:00:00    Friday
# 205332  09:00:00     5554    420 2019-09-27 09:00:00    Friday
# 205331  05:00:00     5554    420 2019-09-27 05:00:00    Friday

# %% [markdown]
# # Getting the Maximum value:

# %%
mta_daily = (mta_all_files.groupby(['C/A', 'UNIT', 'SCP', 'STATION', 'DATE','EXITS'],as_index=False)\
             .ENTRIES.first())
mta_daily.sample(10)
# Out:
#            C/A  UNIT       SCP          STATION        DATE     EXITS  \
# 947675    N091  R029  02-05-01      CHAMBERS ST  07/19/2019  11916390
# 2997406   R528  R097  00-00-02    JUNCTION BLVD  08/19/2019    140215
# 1140344   N193  R337  00-00-01      BEACH 44 ST  09/14/2019   1406025
# 600713    J005  R353  00-06-00       LORIMER ST  08/23/2019    107641
# 1327863  N325A  R218  00-03-01      ELMHURST AV  08/19/2019     22573
# 455473    E011  R371  00-00-02            79 ST  05/27/2019   2932831
# 21124     A010  R080  00-00-05       57 ST-7 AV  08/16/2019    505208
# 1565644   N506  R022  00-00-00  34 ST-HERALD SQ  08/05/2019  12685006
# 1951550  PTH16  R550  01-00-04       LACKAWANNA  06/14/2019      1778
# 1217385   N301  R113  00-00-00             7 AV  06/25/2019   7513124
#
#           ENTRIES
# 947675   12131733
# 2997406    290181
# 1140344   1125139
# 600713     167764
# 1327863     18456
# 455473   10133868
# 21124     1733151
# 1565644   7250979
# 1951550      1131
# 1217385   5746704

# %%
mta_daily[["PREV_DATE", "PREV_ENTRIES","PREV_EXITS"]] = (mta_daily.groupby(["C/A", "UNIT", "SCP", "STATION"])\
                                                         ["DATE","ENTRIES","EXITS"].apply(lambda grp: grp.shift(1)))
# Out:
# <ipython-input-27-4e1632375919>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   mta_daily[["PREV_DATE", "PREV_ENTRIES","PREV_EXITS"]] = (mta_daily.groupby(["C/A", "UNIT", "SCP", "STATION"])\

# %%
mta_daily.dropna(subset=["PREV_DATE"], axis=0, inplace=True)
mta_daily.sample(10)
# Out:
#            C/A  UNIT       SCP          STATION        DATE     EXITS  \
# 2396454   R203  R043  00-05-01          WALL ST  09/25/2019    849128
# 311167    B034  R264  01-06-01       OCEAN PKWY  09/04/2019    438927
# 2608482   R247  R178  01-03-02            77 ST  06/23/2019  15362578
# 919633    N083  R138  01-02-02   W 4 ST-WASH SQ  09/15/2019    362657
# 874108    N071  R013  00-00-00   34 ST-PENN STA  06/06/2019  16817874
# 1722737   N557  R130  00-03-00        KINGS HWY  06/23/2019   1413252
# 2966062   R523  R147  00-00-03   61 ST WOODSIDE  06/01/2019   5300800
# 1653830   N531  R129  01-00-01        BERGEN ST  07/07/2019   3967253
# 2737105   R307  R207  01-05-00           135 ST  06/08/2019         0
# 2540390  R238A  R046  02-03-01  GRD CNTRL-42 ST  06/22/2019    311914
#
#          ENTRIES   PREV_DATE  PREV_ENTRIES  PREV_EXITS
# 2396454  5169552  09/25/2019     5169086.0    849090.0
# 311167   3190687  09/03/2019     3190668.0    438911.0
# 2608482  1794153  06/23/2019     1794130.0  15362363.0
# 919633    913728  09/15/2019      913475.0    362541.0
# 874108   5980299  06/06/2019     5979818.0  16817016.0
# 1722737   817395  06/23/2019      817309.0   1413086.0
# 2966062  2752587  06/01/2019     2752413.0   5300545.0
# 1653830  2836677  07/07/2019     2836612.0   3967174.0
# 2737105     3282  06/07/2019        3281.0         0.0
# 2540390  1715916  06/22/2019     1715315.0    311854.0

# %%
#Max value for entries

Q3= mta_all_files["ENTRIES"].quantile(q=0.75)
Q1= mta_all_files["ENTRIES"].quantile(q=0.25)

IQR = Q3-Q1
Maximum_entries = Q3+1.5+IQR

# %%
#plotting the boxplot to see anomlies

sns.boxplot(mta_all_files[mta_all_files["ENTRIES"]<=Maximum_entries].ENTRIES)
plt.savefig('BoxplotEntreis.png');
# Out:
# C:\Users\rawan\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#Max value for existes
Q3= mta_all_files["EXITS"].quantile(q=0.75)
Q1= mta_all_files["EXITS"].quantile(q=0.25)

IQR = Q3-Q1
Maximum_exits = Q3+1.5+IQR

# %%
#plotting the boxplot to see anomlies

sns.boxplot(mta_all_files[mta_all_files["EXITS"]<=Maximum_exits].EXITS)
plt.savefig('BoxplotExists.png');
# Out:
# C:\Users\rawan\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# Fixing the counter for entries

def get_daily_counts_for_entries(row, max_counter):
    counter = row["ENTRIES"] - row["PREV_ENTRIES"]
    if counter < 0:
        # Counter reversed?
        counter = -counter
    if counter > max_counter:
        # Counter reset to 0?
        counter = min(row["ENTRIES"], row["PREV_ENTRIES"])
    if counter > max_counter:
        # Still too big?
        return 0
    return counter

# %%
# daily entries column

mta_daily["DAILY_ENTRIES"] = mta_daily.apply(get_daily_counts_for_entries, axis=1, max_counter=Maximum_entries)
mta_daily.head()
# Out:
#     C/A  UNIT       SCP STATION        DATE    EXITS  ENTRIES   PREV_DATE  \
# 1  A002  R051  02-00-00   59 ST  05/25/2019  2396415  7071844  05/25/2019
# 2  A002  R051  02-00-00   59 ST  05/25/2019  2396443  7071864  05/25/2019
# 3  A002  R051  02-00-00   59 ST  05/25/2019  2396500  7071943  05/25/2019
# 4  A002  R051  02-00-00   59 ST  05/25/2019  2396555  7072182  05/25/2019
# 5  A002  R051  02-00-00   59 ST  05/25/2019  2396593  7072456  05/25/2019
#
#    PREV_ENTRIES  PREV_EXITS  DAILY_ENTRIES
# 1     7071830.0   2396411.0           14.0
# 2     7071844.0   2396415.0           20.0
# 3     7071864.0   2396443.0           79.0
# 4     7071943.0   2396500.0          239.0
# 5     7072182.0   2396555.0          274.0

# %%
# Fixing the counter for exits

def get_daily_counts_for_exits(row, max_counter):
    counter = row["EXITS"] - row["PREV_EXITS"]
    if counter < 0:
        # Counter reversed?
        counter = -counter
    if counter > max_counter:
        # Counter reset to 0?
        counter = min(row["EXITS"], row["PREV_EXITS"])
    if counter > max_counter:
        # Still too big?
        return 0
    return counter

# %%
# daily exits column

mta_daily["DAILY_EXITS"] = mta_daily.apply(get_daily_counts_for_exits, axis=1, max_counter=Maximum_exits)
mta_daily.head()
# Out:
#     C/A  UNIT       SCP STATION        DATE    EXITS  ENTRIES   PREV_DATE  \
# 1  A002  R051  02-00-00   59 ST  05/25/2019  2396415  7071844  05/25/2019
# 2  A002  R051  02-00-00   59 ST  05/25/2019  2396443  7071864  05/25/2019
# 3  A002  R051  02-00-00   59 ST  05/25/2019  2396500  7071943  05/25/2019
# 4  A002  R051  02-00-00   59 ST  05/25/2019  2396555  7072182  05/25/2019
# 5  A002  R051  02-00-00   59 ST  05/25/2019  2396593  7072456  05/25/2019
#
#    PREV_ENTRIES  PREV_EXITS  DAILY_ENTRIES  DAILY_EXITS
# 1     7071830.0   2396411.0           14.0          4.0
# 2     7071844.0   2396415.0           20.0         28.0
# 3     7071864.0   2396443.0           79.0         57.0
# 4     7071943.0   2396500.0          239.0         55.0
# 5     7072182.0   2396555.0          274.0         38.0

# %% [markdown]
# # Calculate the traffic:

# %%
#adding the traffic

mta_daily['Traffic']= mta_daily.DAILY_ENTRIES + mta_daily.DAILY_EXITS

# %%
mta_daily.head()
# Out:
#     C/A  UNIT       SCP STATION        DATE    EXITS  ENTRIES   PREV_DATE  \
# 1  A002  R051  02-00-00   59 ST  05/25/2019  2396415  7071844  05/25/2019
# 2  A002  R051  02-00-00   59 ST  05/25/2019  2396443  7071864  05/25/2019
# 3  A002  R051  02-00-00   59 ST  05/25/2019  2396500  7071943  05/25/2019
# 4  A002  R051  02-00-00   59 ST  05/25/2019  2396555  7072182  05/25/2019
# 5  A002  R051  02-00-00   59 ST  05/25/2019  2396593  7072456  05/25/2019
#
#    PREV_ENTRIES  PREV_EXITS  DAILY_ENTRIES  DAILY_EXITS  Traffic
# 1     7071830.0   2396411.0           14.0          4.0     18.0
# 2     7071844.0   2396415.0           20.0         28.0     48.0
# 3     7071864.0   2396443.0           79.0         57.0    136.0
# 4     7071943.0   2396500.0          239.0         55.0    294.0
# 5     7072182.0   2396555.0          274.0         38.0    312.0

# %%
mta_daily.describe()
# Out:
#               EXITS       ENTRIES  PREV_ENTRIES    PREV_EXITS  DAILY_ENTRIES  \
# count  3.239217e+06  3.239217e+06  3.239217e+06  3.239217e+06   3.239217e+06
# mean   3.604090e+07  4.289717e+07  4.289851e+07  3.604050e+07   5.489117e+02
# std    2.028631e+08  2.202177e+08  2.202227e+08  2.028584e+08   3.979661e+04
# min    0.000000e+00  0.000000e+00  0.000000e+00  0.000000e+00   0.000000e+00
# 25%    2.591040e+05  4.875250e+05  4.876150e+05  2.591800e+05   2.400000e+01
# 50%    1.505875e+06  2.556464e+06  2.556547e+06  1.505947e+06   1.000000e+02
# 75%    5.043332e+06  7.031822e+06  7.031767e+06  5.043336e+06   2.620000e+02
# max    2.124055e+09  2.129289e+09  2.129289e+09  2.124055e+09   1.244717e+07
#
#         DAILY_EXITS       Traffic
# count  3.239217e+06  3.239217e+06
# mean   3.951141e+02  9.440258e+02
# std    2.735497e+04  6.108490e+04
# min    0.000000e+00  0.000000e+00
# 25%    2.000000e+01  6.700000e+01
# 50%    7.100000e+01  2.180000e+02
# 75%    1.890000e+02  4.910000e+02
# max    8.702864e+06  2.024027e+07

# %%
# Dropping the "PREV_ENTRIES","PREV_EXITS Columns. To prevent errors in multiple run of cell, errors on drop is ignored

mta_daily = mta_daily.drop(["PREV_ENTRIES","PREV_EXITS"], axis=1, errors="ignore")
mta_daily.head()
# Out:
#     C/A  UNIT       SCP STATION        DATE    EXITS  ENTRIES   PREV_DATE  \
# 1  A002  R051  02-00-00   59 ST  05/25/2019  2396415  7071844  05/25/2019
# 2  A002  R051  02-00-00   59 ST  05/25/2019  2396443  7071864  05/25/2019
# 3  A002  R051  02-00-00   59 ST  05/25/2019  2396500  7071943  05/25/2019
# 4  A002  R051  02-00-00   59 ST  05/25/2019  2396555  7072182  05/25/2019
# 5  A002  R051  02-00-00   59 ST  05/25/2019  2396593  7072456  05/25/2019
#
#    DAILY_ENTRIES  DAILY_EXITS  Traffic
# 1           14.0          4.0     18.0
# 2           20.0         28.0     48.0
# 3           79.0         57.0    136.0
# 4          239.0         55.0    294.0
# 5          274.0         38.0    312.0

# %%
#check for corrlation

plt.figure(figsize=(8,4))
sns.heatmap(mta_daily.corr(),cmap='Greens',annot=True)
plt.savefig('heatmap.png');

# %% [markdown]
# # Finding the Traffic by station:

# %%
# Come up with daily time series for each STATION, by adding up all the turnstiles in a station.

station_totals = mta_daily.groupby('STATION').sum()\
                        .sort_values('Traffic', ascending=False).reset_index()
station_totals[:15]
# Out:
#             STATION          EXITS        ENTRIES  DAILY_ENTRIES  DAILY_EXITS  \
# 0   GRD CNTRL-42 ST  2326633025623  1634710706822     94228325.0   39070717.0
# 1         FULTON ST  2537588628391  3265144291937     50513882.0   49396839.0
# 2   THIRTY THIRD ST     1596518836     2105965367     54346880.0   40791388.0
# 3            125 ST  2953117988050  4832786514017     44245659.0   35283134.0
# 4          CANAL ST  4070367654465  3025725943394     58348685.0   21016402.0
# 5    EXCHANGE PLACE     1390839763     1450535682     35182891.0   33089739.0
# 6             14 ST  2230348223408  3058406080865     30748462.0   33488181.0
# 7    34 ST-PENN STA  3086994156043  2769733118020     29978775.0   29083879.0
# 8   PAVONIA/NEWPORT     1362616630     1187196492     26385655.0   31052616.0
# 9       SOUTH FERRY    19091111930   112165099000     27905743.0   25339173.0
# 10  42 ST-PORT AUTH  4683509866823  5594030399753     28655571.0   23750283.0
# 11            72 ST  2483928606683  1668798177907     30041129.0   22359719.0
# 12            23 ST  3705428606434  4234957066557     27808369.0   23019127.0
# 13     BOROUGH HALL    42955836504   133717201532     34367357.0   14213937.0
# 14  34 ST-HERALD SQ  4044655200952  3155260300086     28270982.0   18347137.0
#
#         Traffic
# 0   133299042.0
# 1    99910721.0
# 2    95138268.0
# 3    79528793.0
# 4    79365087.0
# 5    68272630.0
# 6    64236643.0
# 7    59062654.0
# 8    57438271.0
# 9    53244916.0
# 10   52405854.0
# 11   52400848.0
# 12   50827496.0
# 13   48581294.0
# 14   46618119.0

# %%
#top traffieced stations in 2019

plt.figure(figsize=[25,20])

sns.barplot(x='Traffic', y='STATION', data=station_totals[:30], color='sandybrown')
plt.title('Top Most Busiest Stations of 2019', fontsize=20)
plt.xlabel('Total Traffic', fontsize=18)
plt.ylabel('Station', fontsize=18);
plt.savefig('Top statios.png');

# %%
#Top ten statios

plt.figure(figsize=(10,5))
plt.bar(x=station_totals['STATION'][:10], height=station_totals['Traffic'][:10],  color="sandybrown")# top ten 
plt.xticks(rotation=60)
plt.xlabel("STATIONS")
plt.ylabel("Traffic")
plt.savefig('Top ten statios.png');

# %%
#the traffic for ta single turnstile (59 st station)

single_turnstile = mta_daily[(mta_daily["C/A"] == "A002") & 
(mta_daily["UNIT"] == "R051") & 
(mta_daily["SCP"] == "02-00-00") & 
(mta_daily["STATION"] == "59 ST")]

single_turnstile.head()
# Out:
#     C/A  UNIT       SCP STATION        DATE    EXITS  ENTRIES   PREV_DATE  \
# 1  A002  R051  02-00-00   59 ST  05/25/2019  2396415  7071844  05/25/2019
# 2  A002  R051  02-00-00   59 ST  05/25/2019  2396443  7071864  05/25/2019
# 3  A002  R051  02-00-00   59 ST  05/25/2019  2396500  7071943  05/25/2019
# 4  A002  R051  02-00-00   59 ST  05/25/2019  2396555  7072182  05/25/2019
# 5  A002  R051  02-00-00   59 ST  05/25/2019  2396593  7072456  05/25/2019
#
#    DAILY_ENTRIES  DAILY_EXITS  Traffic
# 1           14.0          4.0     18.0
# 2           20.0         28.0     48.0
# 3           79.0         57.0    136.0
# 4          239.0         55.0    294.0
# 5          274.0         38.0    312.0

# %%
#ploting that single turnstile

plt.figure(figsize=(15,5))
plt.plot(single_turnstile['DATE'][:50], single_turnstile['Traffic'][:50])#size50
plt.ylabel('number of Traffic in a station')
plt.xlabel('Date')
plt.xticks(rotation=45)
plt.title('Daily Entries for the Turnstile A002/R051/02-00-00 at 59 ST Station')
plt.savefig('Daily Entries for the Turnstile.png');

# %%
# week of column

mta_daily['WEEK_DAY'] = pd.to_datetime(mta_daily['DATE']).dt.dayofweek

mta_daily.tail()
# Out:
#            C/A  UNIT       SCP        STATION        DATE  EXITS  ENTRIES  \
# 3244165  TRAM2  R469  00-05-01  RIT-ROOSEVELT  09/23/2019    420     5554
# 3244166  TRAM2  R469  00-05-01  RIT-ROOSEVELT  09/24/2019    420     5554
# 3244167  TRAM2  R469  00-05-01  RIT-ROOSEVELT  09/25/2019    420     5554
# 3244168  TRAM2  R469  00-05-01  RIT-ROOSEVELT  09/26/2019    420     5554
# 3244169  TRAM2  R469  00-05-01  RIT-ROOSEVELT  09/27/2019    420     5554
#
#           PREV_DATE  DAILY_ENTRIES  DAILY_EXITS  Traffic  WEEK_DAY
# 3244165  09/22/2019            0.0          0.0      0.0         0
# 3244166  09/23/2019            0.0          0.0      0.0         1
# 3244167  09/24/2019            0.0          0.0      0.0         2
# 3244168  09/25/2019            0.0          0.0      0.0         3
# 3244169  09/26/2019            0.0          0.0      0.0         4

# %%
#Get entries by a week

def get_week_list(input_frame, column_name, num_days):
   
    window = 1   # starts at 1 because first day 0 is in second row
    week_list = []
    while window < len(input_frame)-num_days:  
        week_list.append(input_frame[column_name][window:window+num_days])  
        window+=num_days
    return week_list

# %%
#caling the get_week_list
input_frame = mta_daily[mta_daily['STATION'] == 'RIT-ROOSEVELT']
column_name = 'DAILY_ENTRIES'
num_days = 7

#get_week_list(input_frame, column_name, num_days)

# %%
#plot for
x= np.arange(7)
weeks = get_week_list(input_frame, column_name, num_days)
plt.figure(figsize = (15, 5))
plt.xlabel('Week day')
plt.ylabel('Daily entries')
plt.title('Weekday compared to daily entries')
for i in weeks[:10]:   #plotting 10 weeks for a station RIT-ROOSEVELT
    plt.bar(x, i);

# %%
#histogram for the station totals

plt.hist(station_totals['Traffic'])
plt.xticks();
plt.xlabel("DAILY_ENTRIES_EXITS")
plt.ylabel("stations total traffic")
plt.savefig('hist.png');

# %%
#Top ten stations
stations_top10 = (mta_daily.groupby(['STATION'])['Traffic'].sum()
                   .reset_index()
                   .sort_values(by='Traffic',ascending=False) 
                   .STATION.head(10))
stations_top10
# Out:
# 232    GRD CNTRL-42 ST
# 225          FULTON ST
# 351    THIRTY THIRD ST
# 9               125 ST
# 172           CANAL ST
# 212     EXCHANGE PLACE
# 13               14 ST
# 61      34 ST-PENN STA
# 316    PAVONIA/NEWPORT
# 340        SOUTH FERRY
# Name: STATION, dtype: object

# %%
mta_daily.head()
# Out:
#     C/A  UNIT       SCP STATION        DATE    EXITS  ENTRIES   PREV_DATE  \
# 1  A002  R051  02-00-00   59 ST  05/25/2019  2396415  7071844  05/25/2019
# 2  A002  R051  02-00-00   59 ST  05/25/2019  2396443  7071864  05/25/2019
# 3  A002  R051  02-00-00   59 ST  05/25/2019  2396500  7071943  05/25/2019
# 4  A002  R051  02-00-00   59 ST  05/25/2019  2396555  7072182  05/25/2019
# 5  A002  R051  02-00-00   59 ST  05/25/2019  2396593  7072456  05/25/2019
#
#    DAILY_ENTRIES  DAILY_EXITS  Traffic  WEEK_DAY
# 1           14.0          4.0     18.0         5
# 2           20.0         28.0     48.0         5
# 3           79.0         57.0    136.0         5
# 4          239.0         55.0    294.0         5
# 5          274.0         38.0    312.0         5

# %% [markdown]
# Loading the wealthiest neighborhoods dataset:

# %%
#station by neighborhood load data

stationsBydistrect=pd.read_csv('C:/Users/rawan/Desktop/MyProject1/StationsbyNeighborhood.csv')

# %%
stationsBydistrect.head()
# Out:
#       NEIGHBORHOOD         MAP NAME MTA DATA SET IDENTIFIER
# 0  Upper East Side  86 ST-2 AVE 456             86 ST-2 AVE
# 1  Upper East Side  96 ST-2 AVE 456             96 ST-2 AVE
# 2  Upper East Side          96 ST Q                   96 ST
# 3  Upper East Side            77 St                   77 ST
# 4  Upper East Side            72 St                   72 ST

# %%
#NEIGHBORHOOD with the most number of metro stations

stationsBydistrect['NEIGHBORHOOD'].value_counts().plot(kind='bar')
plt.savefig('NEIGHBORHOOD with the most number of metro stations.png');

# %%
#Matching the stations names in both datasetes

def get_station_name(row, col_name, station_names, check_length = False):
   
    row_name = row[col_name]
    row_name = re.sub('th', '', row_name)
    row_name = re.sub('rd', '', row_name)
    row_name = re.sub('nd', '', row_name)
    row_name = re.sub('-', '', row_name).upper()
    similarity = 0
    similar_name = ''
    for name in station_names:
        if check_length:
            if len(name) < 14:
                name += "".join(['-' for i in range(len(name), 14)])
        ratio = SequenceMatcher(None, row_name, name).ratio()
        if ratio > similarity:
            similarity = ratio
            similar_name = name.strip('-')
    return similar_name

# %%
stationsBydistrect['MTA_name'] = stationsBydistrect.apply(get_station_name, axis = 1, col_name = "MAP NAME", \
                                        station_names = mta_daily['STATION'].unique())

# %%
stationsBydistrect.head()
# Out:
#       NEIGHBORHOOD         MAP NAME MTA DATA SET IDENTIFIER     MTA_name
# 0  Upper East Side  86 ST-2 AVE 456             86 ST-2 AVE  86 ST-2 AVE
# 1  Upper East Side  96 ST-2 AVE 456             96 ST-2 AVE  96 ST-2 AVE
# 2  Upper East Side          96 ST Q                   96 ST        96 ST
# 3  Upper East Side            77 St                   77 ST        77 ST
# 4  Upper East Side            72 St                   72 ST        72 ST

# %%
#Top 10 stations in wealthie NEIGHBORHOOD 
#take the stations in wealthiest distrect and get top ten 

stationsBydistrect_list = stationsBydistrect['MTA_name']

stationsBydistrect_stations =mta_daily[mta_daily['STATION'].isin(stationsBydistrect_list)].sort_values(by = 'Traffic', ascending = False)

stationsBydistrect_top10 = \
    (stationsBydistrect_stations.groupby(['STATION'])['Traffic'].sum()
                   .reset_index()
                   .sort_values(by='Traffic',ascending=False) 
                   .STATION.head(10))

# %%
stationsBydistrect_top10.head(30)
# Out:
# 31    GRD CNTRL-42 ST
# 23           CANAL ST
# 1               14 ST
# 12              72 ST
# 3               23 ST
# 21       BOROUGH HALL
# 2      14 ST-UNION SQ
# 27     CHRISTOPHER ST
# 26        CHAMBERS ST
# 9      59 ST COLUMBUS
# Name: STATION, dtype: object

# %%
#a box plot showing the top 10 busiest stations in wealthiest neighborhoods
sns.boxplot(x='Traffic', y='STATION', \
            data=stationsBydistrect_stations[stationsBydistrect_stations['STATION'].isin(stationsBydistrect_top10)], \
            order = stationsBydistrect_top10, showfliers = False).set_title('Top 10 Busiest Stations in wealthiest Neighborhoods')
plt.savefig('Top 10 Busiest Stations in wealthiest NeighborhoodsBoxplot.png');

# %%
sns.barplot(x='Traffic', y='STATION', \
            data=stationsBydistrect_stations[stationsBydistrect_stations['STATION'].isin(stationsBydistrect_top10)], \
            order = stationsBydistrect_top10).set_title('Top 10 Busiest Stations in wealthiest Neighborhoods')
plt.savefig('Top 10 Busiest Stations in wealthiest NeighborhoodsBoxplot.png');

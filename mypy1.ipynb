# %%
import pandas as pd
import numpy as np
import glob as gg
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#path to my files fro the monthes of 6,7,8,9 of 2019 
Path_csv = "/Users/rawan/Desktop/MyProject1/data"

Csv_all =gg.glob(Path_csv + "/*.txt")
list_of_allcsv= []# all data in will be added to the list

for i in Csv_all:
    df = pd.read_csv(i)
    list_of_allcsv.append(df)

# %%
mta_all_files= pd.concat(list_of_allcsv)

# %%
mta_all_files.head()
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/25/2019  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/25/2019  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/25/2019  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/25/2019  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/25/2019  16:00:00
#
#       DESC  ENTRIES  \
# 0  REGULAR  7071830
# 1  REGULAR  7071844
# 2  REGULAR  7071864
# 3  REGULAR  7071943
# 4  REGULAR  7072182
#
#    EXITS
# 0                                            2396411
# 1                                            2396415
# 2                                            2396443
# 3                                            2396500
# 4                                            2396555

# %%
mta_all_files.tail()
# Out:
#           C/A  UNIT       SCP        STATION LINENAME DIVISION        DATE  \
# 205331  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  09/27/2019
# 205332  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  09/27/2019
# 205333  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  09/27/2019
# 205334  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  09/27/2019
# 205335  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  09/27/2019
#
#             TIME     DESC  ENTRIES  \
# 205331  05:00:00  REGULAR     5554
# 205332  09:00:00  REGULAR     5554
# 205333  13:00:00  REGULAR     5554
# 205334  17:00:00  REGULAR     5554
# 205335  21:00:00  REGULAR     5554
#
#         EXITS
# 205331                                                420
# 205332                                                420
# 205333                                                420
# 205334                                                420
# ...

# %%
mta_all_files.shape
# Out:
# (3714064, 11)

# %%
mta_all_files.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3714064 entries, 0 to 205335
# Data columns (total 11 columns):
#  #   Column                                                                Dtype
# ---  ------                                                                -----
#  0   C/A                                                                   object
#  1   UNIT                                                                  object
#  2   SCP                                                                   object
#  3   STATION                                                               object
#  4   LINENAME                                                              object
#  5   DIVISION                                                              object
#  6   DATE                                                                  object
#  7   TIME                                                                  object
# ...

# %%
mta_all_files.describe()
# Out:
#             ENTRIES  \
# count  3.714064e+06
# mean   4.219184e+07
# std    2.151177e+08
# min    0.000000e+00
# 25%    2.893640e+05
# 50%    2.087000e+06
# 75%    6.677386e+06
# max    2.129289e+09
#
#        EXITS
# count                                       3.714064e+06
# mean                                        3.466461e+07
# std                                         1.982552e+08
# min                                         0.000000e+00
# 25%                                         1.197578e+05
# 50%                                         1.194266e+06
# 75%                                         4.581015e+06
# max                                         2.124055e+09

# %%
mta_all_files
# Out:
#           C/A  UNIT       SCP        STATION LINENAME DIVISION        DATE  \
# 0        A002  R051  02-00-00          59 ST  NQR456W      BMT  05/25/2019
# 1        A002  R051  02-00-00          59 ST  NQR456W      BMT  05/25/2019
# 2        A002  R051  02-00-00          59 ST  NQR456W      BMT  05/25/2019
# 3        A002  R051  02-00-00          59 ST  NQR456W      BMT  05/25/2019
# 4        A002  R051  02-00-00          59 ST  NQR456W      BMT  05/25/2019
# ...       ...   ...       ...            ...      ...      ...         ...
# 205331  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  09/27/2019
# 205332  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  09/27/2019
# 205333  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  09/27/2019
# 205334  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  09/27/2019
# 205335  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  09/27/2019
#
#             TIME     DESC  ENTRIES  \
# ...

# %%
#check corrlation
plt.figure(figsize=(8,4))
sns.heatmap(df.corr(),cmap='Greens',annot=True)
# Out:
# <AxesSubplot:>

# %%
mta_all_files.shape

duplicate_num= mta_all_files[mta_all_files.duplicated()]
print("The number of duplicated rows are:", duplicate_num.shape)
# Out:
# The number of duplicated rows are: (0, 11)
